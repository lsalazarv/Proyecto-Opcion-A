# %%
import numpy as np
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/lsalazarv/Proyecto-Opcion-A/master/planecrashinfo_20181121001952.csv'
df = pd.read_csv(url,index_col=0,skip_blank_lines=False,parse_dates=True,dayfirst=True)

# %%
df
# Out:
#                time                                      location  \
# date
# 1908-09-17    17:18                           Fort Myer, Virginia
# 1909-09-07        ?                       Juvisy-sur-Orge, France
# 1912-07-12    06:30                     Atlantic City, New Jersey
# 1913-08-06        ?            Victoria, British Columbia, Canada
# 1913-09-09  c 18:30                            Over the North Sea
# 1913-10-17  c 10:30                    Near Johannisthal, Germany
# 1915-03-05  c 01:00                               Tienen, Belgium
# 1915-09-03  c 15:20                         Off Cuxhaven, Germany
# 1916-07-28        ?                         Near Jambol, Bulgeria
# 1916-09-24  c 01:00                           Billericay, England
# 1916-10-01  c 23:45                          Potters Bar, England
# 1916-11-21        ?                                Mainz, Germany
# 1916-11-28  c 23:45                  Off West Hartlepool, England
# ...
